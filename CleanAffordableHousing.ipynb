# %%
import pandas as pd
from pathlib import Path

#authors:  Acarie Jenkens, Carrie Bates, Corey Monsma, Parker Teske, Stargliy Bobby

# File to Load (use the absolute path per class exercise. Used on an Windows maching)
housing_path = Path("Resources/Affordable_Housing_import.csv")

# Read the housing file
housing_data_df = pd.read_csv(housing_path)

#to upper so we can perform a join
housing_data_df['deathcity'] = housing_data_df['deathcity'].str.upper()

#needed to rename column names for easier import into SQL database columns
housing_data_df.head()
# Out:
#    Year  Town Code    deathcity  2010 Census Units  Government Assisted  \
# 0  2020          1      ANDOVER               1317                 18.0
# 1  2020          2      ANSONIA               8148                349.0
# 2  2020          3      ASHFORD               1903                 32.0
# 3  2020          4         AVON               7389                244.0
# 4  2020          5  BARKHAMSTED               1589                  0.0
#
#    Tenant Rental Assistance   Single Family CHFA/ USDA Mortgages  \
# 0                         1                                   32
# 1                       764                                  147
# 2                         0                                   36
# 3                        16                                   44
# 4                         6                                   23
#
#    Deed Restricted Units  Total Assisted Units  Percent Affordable
# 0                      0                    51                3.87
# ...

# %%
housing_data_df.to_csv("Resources/clean_housing.csv", index=False, header=True)
